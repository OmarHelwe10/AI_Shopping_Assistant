# %%
# !pip install -qU llama-index datasets pinecone-client openai transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 917.6/917.6 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.4/179.4 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.4/221.4 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df=pd.read_csv('/content/drive/MyDrive/product_feed.csv')
df.head()
# Out:
#                        id availability condition  \
# 0        203591-10M_White     in stock       new
# 1   IG5901905750012-BEIGE     in stock       new
# 2  203591-060-BLACK-BLACK     in stock       new
# 3        207281-90H_Multi     in stock       new
# 4    TWOSS23PL00150_Black     in stock       new
#
#                                          description  \
# 0  Everybody loves the comfort of the Crocs Class...
# 1  Inglot brings the freedom system flexi eco pal...
# 2  Featuring bold perforated design, these black ...
# 3  The Kids’ Crocs Littles™ Clog is our iconic Cl...
# 4  A perfect pair of pants for a dynamic and mode...
#
#                                           image_link  \
# 0  https://media.6media.me/media/catalog/product/...
# 1  https://media.6media.me/media/catalog/product/...
# 2  https://media.6media.me/media/catalog/product/...
# 3  https://media.6media.me/media/catalog/product/...
# 4  https://media.6media.me/media/catalog/product/...
#
#                          additional_​​​image_​​​link  \
# 0  https://media.6media.me/media/catalog/product/...
# 1  https://media.6media.me/media/catalog/product/...
# 2  https://media.6media.me/media/catalog/product/...
# 3  https://media.6media.me/media/catalog/product/...
# 4  https://media.6media.me/media/catalog/product/...
#
#                                                 link  \
# 0  https://en-ae.6thstreet.com/classic-lined-slin...
# 1  https://en-ae.6thstreet.com/freedom-system-fle...
# 2  https://en-ae.6thstreet.com/crocs-classic-line...
# 3  https://en-ae.6thstreet.com/littles-graphic-cl...
# 4  https://en-ae.6thstreet.com/buy-trendyol-pants...
#
#                                                title  \
# 0                Crocs Classic Lined Slingback Clogs
# 1         Inglot Freedom System Flexi Eco Palette 01
# 2  Crocs Classic Lined Fur Detail Sling Back Stra...
# 3                         Crocs Littles Graphic Clog
# 4                 Trendyol Solid High Waist Trousers
#
#                                            item_name    price  ...  \
# 0                      Classic Lined Slingback Clogs  279 AED  ...
# 1                Freedom System Flexi Eco Palette 01   85 AED  ...
# 2  Classic Lined Fur Detail Sling Back Strap Clog...  279 AED  ...
# 3                               Littles Graphic Clog  129 AED  ...
# 4                          Solid High Waist Trousers  199 AED  ...
#
#                                                 gtin  \
# 0  191448251298,191448251304,191448251410,1914482...
# 1                                      5901905750012
# 2  887350811186,887350811193,887350811209,8873508...
# 3                                       191448796676
# 4  8683048473108,8683048473115,8683048473122,8683...
#
#                                              ios_url ios_app_name  \
# 0  app6thstreet://pdp/203591-10M_White?utm_source...    6thStreet
# 1  app6thstreet://pdp/IG5901905750012-BEIGE?utm_s...    6thStreet
# 2  app6thstreet://pdp/203591-060-BLACK-BLACK?utm_...    6thStreet
# 3  app6thstreet://pdp/207281-90H_Multi?utm_source...    6thStreet
# 4  app6thstreet://pdp/TWOSS23PL00150_Black?utm_so...    6thStreet
#
#   ios_app_store_id                                android_url  \
# 0       1370217070        app6thstreet://pdp/203591-10M_White
# 1       1370217070   app6thstreet://pdp/IG5901905750012-BEIGE
# 2       1370217070  app6thstreet://pdp/203591-060-BLACK-BLACK
# 3       1370217070        app6thstreet://pdp/207281-90H_Multi
# 4       1370217070    app6thstreet://pdp/TWOSS23PL00150_Black
#
#             android_package android_app_name  \
# 0  com.apparel.app6thstreet        6thStreet
# 1  com.apparel.app6thstreet        6thStreet
# 2  com.apparel.app6thstreet        6thStreet
# 3  com.apparel.app6thstreet        6thStreet
# 4  com.apparel.app6thstreet        6thStreet
#
#                                          mobile_link  \
# 0  https://en-ae.6thstreet.com/classic-lined-slin...
# 1  https://en-ae.6thstreet.com/freedom-system-fle...
# 2  https://en-ae.6thstreet.com/crocs-classic-line...
# 3  https://en-ae.6thstreet.com/littles-graphic-cl...
# 4  https://en-ae.6thstreet.com/buy-trendyol-pants...
#
#                                       icon_media_url size_availability
# 0  https://6thsteet-images.s3-eu-west-1.amazonaws...               0.9
# 1  https://6thsteet-images.s3-eu-west-1.amazonaws...               1.0
# 2  https://6thsteet-images.s3-eu-west-1.amazonaws...               0.9
# 3  https://6thsteet-images.s3-eu-west-1.amazonaws...               1.0
# 4  https://6thsteet-images.s3-eu-west-1.amazonaws...               1.0
#
# [5 rows x 46 columns]

# %%
df['category']=df['L1 - category']
df['subcategory']=df['L2 - sub-category']

df['gender']=df['L0 - gender']
df=df[['title','description','image_link','category','subcategory','product_type','brand','gender','price','season','color','condition']]

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75879 entries, 0 to 106493
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         75879 non-null  object
#  1   description   75879 non-null  object
#  2   image_link    75879 non-null  object
#  3   category      75879 non-null  object
#  4   subcategory   75879 non-null  object
#  5   product_type  75879 non-null  object
#  6   brand         75879 non-null  object
#  7   gender        75879 non-null  object
#  8   price         75879 non-null  object
#  9   season        75879 non-null  object
#  10  color         75879 non-null  object
#  11  condition     75879 non-null  object
# dtypes: object(12)
# memory usage: 7.5+ MB

# %%
import os
from llama_index import ServiceContext, LLMPredictor, OpenAIEmbedding, PromptHelper
from llama_index.llms import OpenAI
from llama_index.text_splitter import TokenTextSplitter
from llama_index.node_parser import SimpleNodeParser
from llama_index import VectorStoreIndex, SimpleDirectoryReader,KeywordTableIndex
from llama_index import set_global_service_context

# %%
from pathlib import Path
from llama_index import download_loader

PandasCSVReader = download_loader("PandasCSVReader")

loader = PandasCSVReader()
docs = loader.load_data(file=Path('./df.csv'))

# %%
from llama_index import Document
from llama_index.node_parser import SentenceSplitter
import tiktoken

node_parser=SimpleNodeParser()

nodes = node_parser.get_nodes_from_documents(
    docs
)
nodes[0]
# Out:
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# TextNode(id_='506c7279-2df3-40dc-a6a0-08eaddb6f9d0', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='efb20306-1521-4dfe-b3a9-9b45bbea44a4', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='73419ce5836940f574fce74ebd8e59d2071eaf6298c38b9e1a1e00b0269bcf15'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='db6fc96d-2507-432f-ae57-831f5850c80c', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='51c4c0665756bc9f332f9f6f95f648ef34e09375e79a6a6c7c5d000a6854c631')}, hash='8b39f151d5fcc0b22704d9529050f0ba419ed698ebf17ea18afc82cc75a13288', text="Crocs Classic Lined Slingback Clogs, Everybody loves the comfort of the Crocs Classic Clog — and now there’s a toasty lined version to keep the feeling going all season. The soft, fuzzy liner adds to the cushion and comfort, indoors or out. Great as a slipper, yet capable to run errands, too. Croslite™ foam construction keeps them light and easy to wear. The pivoting heel strap gives you a secure fit, or push it forward to just step in and go. The legendary Classic Clog, now with a warm, fuzzy liner\n\xa0\nIncredibly light and easy to wear\n\xa0\nPivoting heel straps for a more secure fit\n\xa0\nGreat indoors or out\n\xa0\nCustomizable with Jibbitz™ charms\n\xa0\nDual Crocs Comfort™: Blissfully supportive. Soft. Cradling comfort., https://media.6media.me/media/catalog/product/cache/e051e343fbed6099e8c148bd11733e32/2/0/203591_10m_alt100.jpg, Shoes, Slippers, clogs, Crocs, Men, 279 AED, SS22, White, new\nInglot Freedom System Flexi Eco Palette 01, Inglot brings the freedom system flexi eco palette made of naturally colored bamboo. The extremely handy, pleasant to the touch palettes reflect a simple yet classy design. The beige colored unique pattern created by the tree rings makes each palette one of a kind., https://media.6media.me/media/catalog/product/cache/e051e343fbed6099e8c148bd11733e32/i/g/ig5901905750012-beige-760x850_12.jpg, Beauty, Makeup, EYES PALETTE, Inglot, Women, 85 AED, SS19, Beige, new\nCrocs Classic Lined Fur Detail Sling Back Strap Clog - Black, Featuring bold perforated design, these black colored clogs from Crocs are a useful addition to your Crocs. Featuring croslite upper and rubber sole for enhanced wear ability, has a fur detail, these clogs flaunt an sling back strap for supreme foot grip and support. Team these with casual, western attire as you get ready for an evening out with friends., https://media.6media.me/media/catalog/product/cache/e051e343fbed6099e8c148bd11733e32/2/0/203591-060-black-black-760x850_1.jpg, Shoes, Slippers, Sandals, Crocs, Women, 279 AED, SS19, Black, new\nCrocs Littles Graphic Clog, The Kids’ Crocs Littles™ Clog is our iconic Classic Clog reengineered for little feet. Crocs Classic Clogs offer lightweight Iconic Crocs Comfort™, a print for every personality, and an ongoing invitation to be comfortable in your own shoes., https://media.6media.me/media/catalog/product/cache/e051e343fbed6099e8c148bd11733e32/2/0/207281-90h-1.jpg, Footwear, Clogs, clogs, Crocs, Kids, 129 AED, SS21, Multi, new\nRoza Abaya Hand Embroidered Occasional Abaya, The embroidered styles of abaya have captivated the attention of women in today's time and believe us new styles to the traditional abaya look have been introduced, varying considerably throughout or magnificent assortment. Go nowhere as we've got you covered with our wide range of designs under the mesmerizing collection of abaya's. Grab this one now as it can certainly grab the attention of many with it's intricate designs and solid patterns., https://media.6media.me/media/catalog/product/cache/e051e343fbed6099e8c148bd11733e32/r/z/rz0774-1.jpg, Clothing, Modest Wear, Abayas, Roza Abaya, Women, 400 AED, SS22, Black, new\nTrendyol Lining Detailed Blazer Jacket, Now this one is a no brainer. One of the most versatile outfits, a perfectly fit blazer jacket, designed with perfection that  ...

# %%
llm = OpenAI(model='gpt-3.5-turbo', temperature=0, max_tokens=256)

embed_model = OpenAIEmbedding()

prompt_helper = PromptHelper(

  context_window=4096,

  num_output=256,

  chunk_overlap_ratio=0.2,

  chunk_size_limit=None

)

service_context = ServiceContext.from_defaults(

  llm=llm,

  embed_model=embed_model,

  node_parser=node_parser,

  prompt_helper=prompt_helper

)

# %%
index = VectorStoreIndex.from_documents(
    docs,
    service_context = service_context
    )

# %%
# Persisting to disk
index.storage_context.persist(persist_dir="/content/drive/MyDrive/Capstone_Project_Team_3")
